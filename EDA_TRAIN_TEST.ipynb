# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # LOAD THE DATA

# %%
train = pd.read_csv('./data/train.csv')
train.head(1)
# Out:
#          Date                                            Address  \
# 0  2007-05-29  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy  \
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9
#
#    NumMosquitos  WnvPresent
# 0             1           0

# %%
test = pd.read_csv('./data/test.csv')
test.head(1)
# Out:
#    Id        Date                                            Address  \
# 0   1  2008-06-11  4100 North Oak Park Avenue, Chicago, IL 60634,...
#
#                   Species  Block           Street  Trap  \
# 0  CULEX PIPIENS/RESTUANS     41   N OAK PARK AVE  T002
#
#               AddressNumberAndStreet  Latitude  Longitude  AddressAccuracy
# 0  4100  N OAK PARK AVE, Chicago, IL  41.95469 -87.800991                9

# %% [markdown]
# # EDA TRAIN

# %%
train.shape
# Out:
# (10506, 12)

# %%
train.isnull().sum()
# Out:
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# NumMosquitos              0
# WnvPresent                0
# dtype: int64

# %%
train.dtypes
# Out:
# Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# NumMosquitos                int64
# WnvPresent                  int64
# dtype: object

# %%
train.describe().T
# Out:
#                    count       mean        std        min        25%  \
# Block            10506.0  35.687797  24.339468  10.000000  12.000000
# Latitude         10506.0  41.841139   0.112742  41.644612  41.732984
# Longitude        10506.0 -87.699908   0.096514 -87.930995 -87.760070
# AddressAccuracy  10506.0   7.819532   1.452921   3.000000   8.000000
# NumMosquitos     10506.0  12.853512  16.133816   1.000000   2.000000
# WnvPresent       10506.0   0.052446   0.222936   0.000000   0.000000
#
#                        50%        75%        max
# Block            33.000000  52.000000  98.000000
# Latitude         41.846283  41.954690  42.017430
# Longitude       -87.694991 -87.627796 -87.531635
# AddressAccuracy   8.000000   9.000000   9.000000
# NumMosquitos      5.000000  17.000000  50.000000
# WnvPresent        0.000000   0.000000   1.000000

# %%
# Date needs to be set as datetime
train['Date'] = pd.to_datetime(train['Date'], infer_datetime_format=True)

# %%
# Transforming object features to categorical features
train['Address'] = train['Address'].astype('category')
train['Species'] = train['Species'].astype('category')
train['Street']  = train['Street'].astype('category')
train['Trap']    = train['Trap'].astype('category')
train['AddressNumberAndStreet'] = train['AddressNumberAndStreet'].astype('category')

# %%
train.dtypes
# Out:
# Date                      datetime64[ns]
# Address                         category
# Species                         category
# Block                              int64
# Street                          category
# Trap                            category
# AddressNumberAndStreet          category
# Latitude                         float64
# Longitude                        float64
# AddressAccuracy                    int64
# NumMosquitos                       int64
# WnvPresent                         int64
# dtype: object

# %%
#Index of data train
train.index
# Out:
# RangeIndex(start=0, stop=10506, step=1)

# %%
#Reducing name of Species
train['Species'] = train['Species'].str.replace('CULEX ', '')
train['Species'].value_counts()
# Out:
# PIPIENS/RESTUANS    4752
# RESTUANS            2740
# PIPIENS             2699
# TERRITANS            222
# SALINARIUS            86
# TARSALIS               6
# ERRATICUS              1
# Name: Species, dtype: int64

# %%
#Checking for the balance of data on WnvPresent
train['WnvPresent'].value_counts(normalize=True)
# Out:
# 0    0.947554
# 1    0.052446
# Name: WnvPresent, dtype: float64

# %%
#Number of duplicates
train.duplicated(subset=None, keep='first').sum()
# Out:
# 813

# %%
# Creating new column for year and month
train['Day'] = train['Date'].dt.dayofyear
train['Month'] = train['Date'].dt.month
train['Year'] = train['Date'].dt.year

# %%
train['Year'].value_counts()
# Out:
# 2007    3811
# 2013    2392
# 2009    2249
# 2011    2054
# Name: Year, dtype: int64

# %%
train['Month'].value_counts()
# Out:
# 8     3751
# 7     2606
# 9     2218
# 6     1571
# 10     276
# 5       84
# Name: Month, dtype: int64

# %% [markdown]
# ## Train Graphs

# %%
#Average Number of Mosquitos in Trap per Month and Year
_ = sns.pointplot(x='Month', y="NumMosquitos", hue="Year", data=train.groupby(['Year', 'Month'], as_index=False)['NumMosquitos'].mean(),)
_.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
sns.set(font_scale=1.5, rc={'figure.figsize':(8, 8)})
plt.ylabel('Average Number of Mosquitos in Trap')
# Out:
# Text(0,0.5,'Average Number of Mosquitos in Trap')

# %%
#Aveage number of positive cases of WNV  in trap per month and year
_ = sns.pointplot(x='Month', y="WnvPresent", hue="Year", data=train.groupby(['Year', 'Month'], as_index=False)['WnvPresent'].mean(),)
_.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
sns.set(font_scale=1.5, rc={'figure.figsize':(8, 8)})
plt.ylabel('Average Cases of WNV in Trap')
# Out:
# Text(0,0.5,'Average Cases of WNV in Trap')

# %%
#Number of mosquitos in trap vs. % of cases of WNV
sns.set(font_scale=1, rc={'figure.figsize':(6, 6)})
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1 = sns.pointplot(x='Month', y="NumMosquitos", data=train.groupby(['Month'], as_index=False)['NumMosquitos'].mean(),)
plt.ylabel('Average Number of Mosquitos in Trap')
plt.legend(['Number of Mosquitos'], loc=2)
ax2 = ax1.twinx()
ax2 = sns.pointplot(x='Month', y="WnvPresent", linestyles='-.', color='r', data=train.groupby(['Month'], as_index=False)['WnvPresent'].mean(),)
ax1.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
plt.ylabel('Average Cases of WNV in Trap')
plt.legend(['Cases of West Nile Virus'], loc=1);

# %%
#Number of Traps by Species 
sns.countplot(x='Species', data=train)
sns.set(font_scale=0.8, rc={'figure.figsize':(8, 8)})
plt.xticks(rotation=0)
plt.ylabel('Number of Traps by Species')
plt.show()

# %%
#Prescence of WNV by Species of Mosquitos
sns.countplot(x='Species', hue='WnvPresent', data=train)
sns.set(font_scale=0.8, rc={'figure.figsize':(8, 8)})
plt.xticks(rotation=0)
plt.legend(['WNV not present', 'WNV present'], loc=1)
plt.ylabel('Number of Traps with Species')
plt.show()

# %%
#Average number of Mosquitos in Trap per month per species
_ = sns.pointplot(x='Month', y='NumMosquitos', hue='Species', data=train[train['Species'].isin(['PIPIENS', 'PIPIENS/RESTUANS', 'RESTUANS'])].groupby(['Month', 'Species'], as_index=False)['NumMosquitos'].mean(),)
sns.set(font_scale=1.5, rc={'figure.figsize':(8, 8)})
_.set(xticklabels=['May', 'June', 'July', 'August', 'September', 'October'])
plt.ylabel('Average Number of Mosquitos in Trap')
# Out:
# Text(0,0.5,'Average Number of Mosquitos in Trap')

# %%
z = train[train['WnvPresent']==1]

# %%
#Prescence of WNV by Location
sns.countplot(x='AddressNumberAndStreet', hue='WnvPresent', data=z)
sns.set(font_scale=0.8, rc={'figure.figsize':(12, 12)})
plt.xticks(rotation=90)
plt.legend(['WNV present'], loc=1)
plt.ylabel('Number of traps with WNV Present')
plt.show()

# %%
len(train['AddressNumberAndStreet'].value_counts())
# Out:
# 138

# %%
train.groupby(['AddressNumberAndStreet' ,'WnvPresent', 'Latitude', 'Longitude'], as_index=False)['NumMosquitos'].sum().sort_values('NumMosquitos', ascending=False)
# Out:
#                         AddressNumberAndStreet  WnvPresent   Latitude  \
# 686118           1200  S DOTY AVE, Chicago, IL           0  41.673408
# 283039      1000  W OHARE AIRPORT, Chicago, IL           0  41.974689
# 155237   1000  S STONY ISLAND AVE, Chicago, IL           0  41.726465
# 2757111      4100  N OAK PARK AVE, Chicago, IL           0  41.954690
# 1715743          2400  E 105TH ST, Chicago, IL           0  41.704572
# 2818837          4200  W 127TH PL, Chicago, IL           0  41.662014
# 420482           1100  S AVENUE L, Chicago, IL           0  41.702724
# 2324193          3700  E 118TH ST, Chicago, IL           0  41.680946
# 2209986          3500  W 116TH ST, Chicago, IL           0  41.682587
# 4398493        7000  N MOSELL AVE, Chicago, IL           0  42.008314
# 319608              1000  W OHARE, Chicago, IL           0  41.957799
# 302083      1000  W OHARE AIRPORT, Chicago, IL           1  41.974689
# 3358960            5200  S KOLMAR, Chicago, IL           0  41.798697
# 705162           1200  S DOTY AVE, Chicago, IL           1  41.673408
# 4354186  7000   W ARMITAGE AVENUE, Chicago, IL           0  41.916265
# 4879308       8200  S KOSTNER AVE, Chicago, IL           0  41.743402
# 657393          1100  W ROOSEVELT, Chicago, IL           0  41.867108
# 390904        1100  S ASHLAND AVE, Chicago, IL           0  41.868077
# 49317     1000  N CENTRAL PARK DR, Chicago, IL           0  41.899230
# 2590255          4000  E 130TH ST, Chicago, IL           0  41.659112
# 3207146       5000  S CENTRAL AVE, Chicago, IL           0  41.801498
# 876705       1300  S TORRENCE AVE, Chicago, IL           0  41.678618
# 5083232        9100  W HIGGINS RD, Chicago, IL           0  41.992478
# 4916765      8900  S CARPENTER ST, Chicago, IL           0  41.732984
# 4271434        6700  S KEDZIE AVE, Chicago, IL           0  41.771660
# 1144940           1700  W 95TH ST, Chicago, IL           0  41.720848
# 3291722    5100  N MONT CLARE AVE, Chicago, IL           0  41.973845
# 4116520           6500  E 91ST PL, Chicago, IL           0  41.728495
# 2299083    3600  N PITTSBURGH AVE, Chicago, IL           0  41.944869
# 1524703          2200  W 113TH ST, Chicago, IL           0  41.688324
# ...                                        ...         ...        ...
# 5256114          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256115          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256116          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256117          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256118          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256119          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256120          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256121          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256122          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256123          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256124          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256125          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256126          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256127          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256128          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256129          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256130          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256131          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256132          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256133          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256134          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256135          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256136          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256137          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256138          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256139          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256140          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256141          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256142          9800  S AVENUE G, Chicago, IL           1  42.017430
# 5256143          9800  S AVENUE G, Chicago, IL           1  42.017430
#
#          Longitude  NumMosquitos
# 686118  -87.599862       19790.0
# 283039  -87.890615       13326.0
# 155237  -87.585413        9177.0
# 2757111 -87.800991        3210.0
# 1715743 -87.565666        2833.0
# 2818837 -87.724608        2806.0
# 420482  -87.536497        2715.0
# 2324193 -87.535198        2500.0
# 2209986 -87.707973        2389.0
# 4398493 -87.777921        2338.0
# 319608  -87.930995        2103.0
# 302083  -87.890615        2060.0
# 3358960 -87.736812        2002.0
# 705162  -87.599862        1878.0
# 4354186 -87.800515        1826.0
# 4879308 -87.731435        1729.0
# 657393  -87.654224        1724.0
# 390904  -87.666901        1585.0
# 49317   -87.716788        1489.0
# 2590255 -87.538693        1424.0
# 3207146 -87.763416        1415.0
# 876705  -87.559308        1321.0
# 5083232 -87.862995        1271.0
# 4916765 -87.649642        1261.0
# 4271434 -87.703047        1202.0
# 1144940 -87.666014        1119.0
# 3291722 -87.805059        1096.0
# 4116520 -87.600963        1091.0
# 2299083 -87.832763        1084.0
# 1524703 -87.676709        1080.0
# ...            ...           ...
# 5256114 -87.629798           NaN
# 5256115 -87.627796           NaN
# 5256116 -87.627561           NaN
# 5256117 -87.627096           NaN
# 5256118 -87.615989           NaN
# 5256119 -87.614258           NaN
# 5256120 -87.612922           NaN
# 5256121 -87.611560           NaN
# 5256122 -87.605294           NaN
# 5256123 -87.604498           NaN
# 5256124 -87.600963           NaN
# 5256125 -87.600880           NaN
# 5256126 -87.599862           NaN
# 5256127 -87.598865           NaN
# 5256128 -87.590773           NaN
# 5256129 -87.586427           NaN
# 5256130 -87.585487           NaN
# 5256131 -87.585413           NaN
# 5256132 -87.582699           NaN
# 5256133 -87.565666           NaN
# 5256134 -87.562889           NaN
# 5256135 -87.559308           NaN
# 5256136 -87.555510           NaN
# 5256137 -87.546587           NaN
# 5256138 -87.543067           NaN
# 5256139 -87.538693           NaN
# 5256140 -87.536497           NaN
# 5256141 -87.535198           NaN
# 5256142 -87.531657           NaN
# 5256143 -87.531635           NaN
#
# [5256144 rows x 5 columns]

# %% [markdown]
# Observations:
#
# - Address seems irelevant, since we have latitute and logitude.  This
#   feature can be dropped.
# - Almost 95% of WNV is 0, meaning that WNV is not present.  We will
#   need to stratify our training data to avoid a higher presence of 0
#   in our results.
# - Species have 7 categories, so we will need to create dummies
# - The training set has 813 duplicate rows.  Since observations are
#   capped at 50 mosquitos, it is possible that a single observation
#   includes a couple of records. We will leave the   duplicates for
#   this reason, and add up the number of mosquitos with a groupby.

# %% [markdown]
# # EDA TEST

# %%
test.shape
# Out:
# (116293, 11)

# %%
test.isnull().sum()
# Out:
# Id                        0
# Date                      0
# Address                   0
# Species                   0
# Block                     0
# Street                    0
# Trap                      0
# AddressNumberAndStreet    0
# Latitude                  0
# Longitude                 0
# AddressAccuracy           0
# dtype: int64

# %%
test.dtypes
# Out:
# Id                          int64
# Date                       object
# Address                    object
# Species                    object
# Block                       int64
# Street                     object
# Trap                       object
# AddressNumberAndStreet     object
# Latitude                  float64
# Longitude                 float64
# AddressAccuracy             int64
# dtype: object

# %%
test.describe().T
# Out:
#                     count          mean           std        min  \
# Id               116293.0  58147.000000  33571.041765   1.000000
# Block            116293.0     41.131100     24.864726  10.000000
# Latitude         116293.0     41.849389      0.106593  41.644612
# Longitude        116293.0    -87.693658      0.080699 -87.930995
# AddressAccuracy  116293.0      7.954357      1.252733   3.000000
#
#                           25%           50%           75%            max
# Id               29074.000000  58147.000000  87220.000000  116293.000000
# Block               18.000000     39.000000     61.000000      98.000000
# Latitude            41.753411     41.862292     41.951866      42.017430
# Longitude          -87.750938    -87.694991    -87.648860     -87.531635
# AddressAccuracy      8.000000      8.000000      9.000000       9.000000

# %%
# Date needs to be set as datetime
test['Date'] = pd.to_datetime(test['Date'], infer_datetime_format=True)

# %%
# Transforming object features to categorical features
test['Address'] = test['Address'].astype('category')
test['Species'] = test['Species'].astype('category')
test['Street']  = test['Street'].astype('category')
test['Trap']    = test['Trap'].astype('category')
test['AddressNumberAndStreet'] = test['AddressNumberAndStreet'].astype('category')

# %%
test.dtypes
# Out:
# Id                                 int64
# Date                      datetime64[ns]
# Address                         category
# Species                         category
# Block                              int64
# Street                          category
# Trap                            category
# AddressNumberAndStreet          category
# Latitude                         float64
# Longitude                        float64
# AddressAccuracy                    int64
# dtype: object

# %%
#Index of data train
test.index
# Out:
# RangeIndex(start=0, stop=116293, step=1)

# %%
#Reducing name of Species
test['Species'] = test['Species'].str.replace('CULEX ', '')
test['Species'].value_counts()
# Out:
# PIPIENS/RESTUANS     15359
# RESTUANS             14670
# PIPIENS              14521
# SALINARIUS           14355
# TERRITANS            14351
# TARSALIS             14347
# ERRATICUS            14345
# UNSPECIFIED CULEX    14345
# Name: Species, dtype: int64

# %%
#Number of duplicates
test.duplicated(subset=None, keep='first').sum()
# Out:
# 0

# %%
# Creating new column for year and month
test['Day'] = train['Date'].dt.dayofyear
test['Month'] = train['Date'].dt.month
test['Year'] = train['Date'].dt.year

# %%
test['Year'].value_counts()
# Out:
# 2007.0    3811
# 2013.0    2392
# 2009.0    2249
# 2011.0    2054
# Name: Year, dtype: int64

# %%
test['Month'].value_counts()
# Out:
# 8.0     3751
# 7.0     2606
# 9.0     2218
# 6.0     1571
# 10.0     276
# 5.0       84
# Name: Month, dtype: int64

# %% [markdown]
# ## Test Graphs

# %%
#Number of Traps by Species 
sns.countplot(x='Species', data=test)
sns.set(font_scale=0.8, rc={'figure.figsize':(10, 8)})
plt.xticks(rotation=0)
plt.ylabel('Number of Traps by Species')
plt.show()

# %% [markdown]
# Observations:
# - Comparing the test with our train distribution of traps by species
#   we can see that our test data includes relatively uniform
#   observations of each subspecies plus an unknown specie.
# - We will have to homogenize the species categories for train and
#   test.
# - We also noticed that the test data does not have the column
#   NumMosquitos.

# %% [markdown]
# # FEATURE ENGINEERING TRAIN

# %%
#Homogenizing the categories of Species on train 
train_spec_val = sorted(list(train['Species'].unique()))
test_spec_val = sorted(list(test['Species'].unique()))
spec_val_categories = set(train_spec_val + test_spec_val ) 

train['Species'] = pd.Categorical(train['Species'], categories = spec_val_categories)

# %%
#getting dummies for train_trap
train = pd.get_dummies(train, columns=['Species'])

# %%
#dropping duplicates from trai_trap
train.drop_duplicates(inplace=True)

# %%
#dropping number of mosquitos because it is not in test set
train.drop('NumMosquitos', axis=1, inplace=True)

# %%
#train_trap.shape
train.shape
# Out:
# (9693, 21)

# %%
train_trap['Month'].value_counts()
# Out:
# 8     2835
# 7     2120
# 9     1973
# 6     1337
# 10     264
# 5       81
# Name: Month, dtype: int64

# %%
train.to_csv('EDA_TRAIN.csv')

# %% [markdown]
# # FEATURE ENGINEERING TEST

# %%
#Homogenizing the categories of Species on test
test['Species'] = pd.Categorical(test['Species'], categories = spec_val_categories)

# %%
#getting dummies for test
test = pd.get_dummies(test, columns=['Species'])

# %%
#test.shape.  Only difference between train trap and test is columns WnvPresent
test.shape
# Out:
# (116293, 21)

# %%
test.to_csv('EDA_TEST.csv')
